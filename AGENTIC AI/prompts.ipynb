# %%
from dotenv import load_dotenv
from groq import Groq
import os

load_dotenv()

client = Groq(
    api_key=os.getenv("GROQ_API_KEY")
)

print("Connected Successfully")
# Out:
# Connected Successfully

# %%
from groq import Groq

zero_shot = """Classify the Movie Reviews"""

movie_review1 = "Tell me the shathamanam bhavathi movie review"

chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "system",
            "content": zero_shot
        },
        {
            "role": "user",
            "content": movie_review1,
        }
    ],
    model="llama-3.3-70b-versatile",
)
print(chat_completion.choices[0].message.content)
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[2], line 7
#       3 zero_shot = """Classify the Movie Reviews"""
#       4
#       5 movie_review1 = "Tell me the shathamanam bhavathi movie review"
#       6
# ----> 7 chat_completion = client.chat.completions.create(
#       8     messages=[
#       9         {
#      10             "role": "system",
#
# ...

# %%
from groq import Groq

one_shot = """Classify the Movie Review:
The Movie was Bad
Sentiment Tag: Negative
Classify the Movie Review"""

movie_review1 = "How was the shathamanam bhavathi movie review?."

chat_completion = client.chat.completions.create(
    messages=[
         {
            "role": "system",
            "content": zero_shot
        },
        {
            "role": "user",
            "content": movie_review1,
        }
    ],
    model="llama-3.3-70b-versatile",
)
print(chat_completion.choices[0].message.content)
# Out:
# Sharwanand played the lead role in the Shatamanam Bhavathi movie. I am providing the review of the Shatamanam Bhavathi movie based on general information.
#
# Shatamanam Bhavathi is a 2017 Telugu-language romantic comedy film directed by Satish Vegesna. The movie received generally positive reviews from critics and audiences alike. Here are some key points from the reviews:
#
# **Positives:**
#
# 1. **Family-friendly**: The movie was praised for its family-friendly tone, clean comedy, and wholesome entertainment.
# 2. **Performances**: Sharwanand and Anupama Parameswaran's performances were appreciated for their chemistry and acting skills.
# 3. **Direction**: Satish Vegesna's direction was commended for handling the storyline and characters effectively.
# 4. **Music**: The movie's music, composed by Mickey J Meyer, was well-received, with some songs becoming popular hits.
#
# **Negatives:**
#
# ...

# %%
from groq import Groq

few_shot = """Classify the Movie Review:
The Movie was Bad
Sentiment Tag: Negative
Classify the Movie Review:
The Movie was Good
Sentiment Tag: Positive
Classify the Movie Review"""

movie_review1 = "How was the shathamanam bhavathi movie review?."

chat_completion = client.chat.completions.create(
    messages=[
         {
            "role": "system",
            "content": zero_shot
        },
        {
            "role": "user",
            "content": movie_review1,
        }
    ],
    model="llama-3.3-70b-versatile",
)
print(chat_completion.choices[0].message.content)
# Out:
# Shatamanam Bhavati is a 2017 Indian Telugu-language family drama film directed by Satish Vegesna. The movie received generally positive reviews from critics. Here's a summary of the review:
#
# **Positive aspects:**
#
# 1. **Family values**: The movie was praised for its strong emphasis on traditional family values, relationships, and cultural heritage.
# 2. **Performances**: The lead actors, Sharwanand and Anupama Parameswaran, received appreciation for their performances, especially Sharwanand, who played a young man from a joint family.
# 3. **Direction**: Satish Vegesna's direction was commended for handling the complex family dynamics and emotions with sensitivity.
# 4. **Music**: The film's soundtrack, composed by Mickey J Meyer, was well-received, with the songs being melodious and fitting the movie's mood.
#
# **Negative aspects:**
#
# 1. **Predictability**: Some critics found the storyline predictable, with a few clichéd moments.
# ...

# %%
from groq import Groq
cot = """""" 

prompt = """ 
Question:
Ravi says, "She is the daughter of the only son of my grandfather."
Who is the girl to Ravi?
""" 

chat_completion = client.chat.completions.create(
    messages=[
         {
            "role": "system",
            "content": zero_shot
        },
        {
            "role": "user",
            "content": movie_review1,
        }
    ],
    model="llama-3.3-70b-versatile",
)
print(chat_completion.choices[0].message.content)
# Out:
# The movie "Shatamanam Bhavati" is a 2017 Indian Telugu-language family drama film directed by Satish Vegesna. Based on the reviews, here's a general classification:
#
# **Overall Review:** Positive
#
# **Critics' Consensus:** The movie received widespread critical acclaim for its simple yet engaging storyline, strong performances from the cast, and the director's ability to balance humor and emotions.
#
# **Positives:**
#
# * The film's portrayal of traditional family values and relationships was appreciated.
# * The lead actors, Sharwanand and Anupama Parameswaran, delivered impressive performances.
# * The movie's music and cinematography were praised for being soulful and visually appealing.
# * The director's handling of the story, which explores the importance of family bonding and cultural heritage, was commended.
#
# **Negatives:**
#
# * Some critics felt that the movie's pace was slow and the storyline was predictable.
# ...

# %%
import os
from langchain.chat_models import init_chat_model

# Set Gemini API key
os.environ["GOOGLE_API_KEY"] = "AQ.Ab8RN6JG_u_HhG9AZdG-ow-HP-5i96o_7wdIHbiqM6fbPc9H0g"

# Create model
model = init_chat_model(
    "gemini-2.5-flash",
    model_provider="google_genai"
)
# Ask question
response = model.invoke(
    "Tell me about the future in 2030 in about 20 words."
)

print(response.content)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 2
#       1 import os
# ----> 2 from langchain.chat_models import init_chat_model
#       3
#       4 # Set Gemini API key
#       5 os.environ["GOOGLE_API_KEY"] = "AQ.Ab8RN6JG_u_HhG9AZdG-ow-HP-5i96o_7wdIHbiqM6fbPc9H0g"
#
# ModuleNotFoundError: No module named 'langchain'
